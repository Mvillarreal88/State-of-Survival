# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress

# %%
# pull in data from csv
state_data_df = pd.read_csv('Data_csv/state_life_avg.csv')
state_PA_df = pd.read_csv("Data_csv/state_PA_avg.csv")
state_obes_df = pd.read_csv("Data_csv/state_obes_avg.csv")

# %%
state_data_df = state_data_df.sort_values('Difference in male life expectancy, 1985-2010 (years)', ascending=False)
# set x axis and tick locations
x_axis = np.arange(len(state_data_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_data_df["Difference in male life expectancy, 1985-2010 (years)"], 
        color='#FFB300', 
        align="edge")
plt.xticks(tick_locations, state_data_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(-0, 8)
# Set Title and labels
plt.title("Difference in male life expectancy, 1985-2010 (years)")
plt.xlabel("State")
plt.ylabel("Years")
plt.savefig('output_data/Difference in male life expectancy, 1985-2010 (years).png', bbox_inches='tight')
plt.show()

# %%
state_data_df = state_data_df.sort_values('Difference in female life expectancy, 1985-2010 (years)', ascending=False)
# set x axis and tick locations
x_axis = np.arange(len(state_data_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_data_df["Difference in female life expectancy, 1985-2010 (years)"], 
        color='#00ACC1', 
        align="edge")
plt.xticks(tick_locations, state_data_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, 5.5)
# Set Title and labels
plt.title("Difference in female life expectancy, 1985-2010 (years)")
plt.xlabel("State")
plt.ylabel("Years")
plt.savefig('output_data/Difference in female life expectancy, 1985-2010 (years).png', bbox_inches='tight')
plt.show()

# %%
state_PA_df = state_PA_df.sort_values('Difference in male sufficient physical activity prevalence, 2001-2009 (percentage points)', ascending=False)

# set x axis and tick locations
x_axis = np.arange(len(state_PA_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,5))
plt.bar(x_axis, 
        state_PA_df["Difference in male sufficient physical activity prevalence, 2001-2009 (percentage points)"], 
        color='#FFB300', 
        align="edge")
plt.xticks(tick_locations, state_PA_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(-3, 7.5)
# Set Title and labels
plt.title("Difference in male sufficient physical activity prevalence, 2001-2009 (percentage points)")
plt.xlabel("State")
plt.ylabel("Percentage Points")
plt.savefig('output_data/Difference in male sufficient physical activity prevalence.png', bbox_inches='tight')
plt.show()

# %%
state_PA_df = state_PA_df.sort_values('Difference in female sufficient physical activity prevalence, 2001-2009 (percentage points)', ascending=False)
# set x axis and tick locations
x_axis = np.arange(len(state_PA_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_PA_df["Difference in female sufficient physical activity prevalence, 2001-2009 (percentage points)"], 
        color='#00ACC1', 
        align="edge")
plt.xticks(tick_locations, state_PA_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(-1, 11)
# Set Title and labels
plt.title("Difference in female sufficient physical activity prevalence, 2001-2009 (percentage points)")
plt.xlabel("State")
plt.ylabel("Percentage Points")
plt.savefig('output_data/Difference in female sufficient physical activity prevalence, 2001-2009 (percentage points).png', bbox_inches='tight')
plt.show()

# %%
state_obes_df = state_obes_df.sort_values('Difference in male obesity prevalence, 2001-2009 (percentage points)', ascending=False)

# set x axis and tick locations
x_axis = np.arange(len(state_obes_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_obes_df['Difference in male obesity prevalence, 2001-2009 (percentage points)'], 
        color='#FFB300', 
        align='edge')
plt.xticks(tick_locations, state_obes_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, 9.5)
# Set Title and labels
plt.title('Difference in male obesity prevalence, 2001-2009 (percentage points)')
plt.xlabel('State')
plt.ylabel('Percentage Points')
plt.savefig('output_data/Difference in male obesity prevalence, 2001-2009 (percentage points).png', bbox_inches='tight')
plt.show()

# %%
state_obes_df = state_obes_df.sort_values('Difference in female obesity prevalence, 2001-2009 (percentage points)', ascending=False)

# set x axis and tick locations
x_axis = np.arange(len(state_obes_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_obes_df['Difference in female obesity prevalence, 2001-2009 (percentage points)'], 
        color='#00ACC1', 
        align='edge')
plt.xticks(tick_locations, state_obes_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, 9.5)
# Set Title and labels
plt.title('Difference in female obesity prevalence, 2001-2009 (percentage points)')
plt.xlabel('State')
plt.ylabel('Percentage Points')
plt.savefig('output_data/Difference in female obesity prevalence, 2001-2009 (percentage points).png', bbox_inches='tight')
plt.show()

# %%
state_le_df = state_data_df[['State', 'Male life expectancy, 2000 (years)', 'Female life expectancy, 2000 (years)', 'Male life expectancy, 2005 (years)', 'Female life expectancy, 2005 (years)', 'Male life expectancy, 2010 (years)', 'Female life expectancy, 2010 (years)']]
state_le_df['male avg'] = ((state_data_df['Male life expectancy, 2000 (years)'] + 
                        state_data_df['Male life expectancy, 2005 (years)'] + state_data_df['Male life expectancy, 2010 (years)'])/3)
state_le_df['female avg'] = ((state_data_df['Female life expectancy, 2000 (years)'] + 
                        state_data_df['Female life expectancy, 2005 (years)'] + state_data_df['Female life expectancy, 2010 (years)'])/3)
state_le_df['Average Life Expectancy'] = ((state_le_df['male avg'] + state_le_df['female avg'])/2)

# set x and y values
x_values = state_PA_df["Difference in male sufficient physical activity prevalence, 2001-2009 (percentage points)"]
y_values = state_obes_df['Difference in male obesity prevalence, 2001-2009 (percentage points)']
# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# variable for calculation of regression line
regress_values = x_values * slope + intercept
# variable for equation of slope intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-value is: {rvalue}")
# scatter plot of weight and average tumor volume
plt.scatter(x_values,y_values, edgecolors='black',s=35)
# plot the line of the slope intercept equation
plt.plot(x_values,regress_values,"red")
# style the box for the equation
le_bbox = dict(boxstyle="round,pad=0.5", fc="r", ec="k", lw='1',)

r_value = f'r = {rvalue}'
# add the equation to the plot
plt.annotate(r_value,
            xy=(0, 1.5),
            xycoords='axes fraction',
            xytext=(0.58, .37),
            fontsize=10,
            color='red')
# set the title and axis labels
plt.xlabel('Sufficient Physical Activity Prevalence')
plt.ylabel('Obesity Prevalence')
plt.title('Female')
plt.savefig("output_data/Difference in Female Physical Activity Prevalence vs. Obesity Prevalence 2001-2009.png")

plt.show()
# Out:
# C:\Users\Mastermind\anaconda3\envs\PyEnv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Mastermind\anaconda3\envs\PyEnv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Mastermind\anaconda3\envs\PyEnv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# ...

# %%
# set x and y values
x_values = state_PA_df["Difference in male sufficient physical activity prevalence, 2001-2009 (percentage points)"]
y_values = state_obes_df['Difference in male obesity prevalence, 2001-2009 (percentage points)']
# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# variable for calculation of regression line
regress_values = x_values * slope + intercept
# variable for equation of slope intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-value is: {rvalue}")
# scatter plot of weight and average tumor volume
plt.scatter(x_values,y_values, edgecolors='black',s=35)
# plot the line of the slope intercept equation
plt.plot(x_values,regress_values,"red")
# style the box for the equation
le_bbox = dict(boxstyle="round,pad=0.5", fc="r", ec="k", lw='1',)

r_value = f'r = {rvalue}'
# add the equation to the plot
plt.annotate(r_value,
            xy=(0, 1.5),
            xycoords='axes fraction',
            xytext=(0.56, .40),
            fontsize=10,
            color='red')
# set the title and axis labels
plt.xlabel('Sufficient Physical Activity Prevalence')
plt.ylabel('Obesity Prevalence')
plt.title('Male')
plt.savefig("output_data/Difference in Male Physical Activity Prevalence vs. Obesity Prevalence 2001-2009.png")

plt.show()
# Out:
# The r-value is: -0.1509791725666674

# %%
state_data_df = state_data_df.sort_values('Difference in female life expectancy, 1985-2010 (years)', ascending=False)

state_le_df = state_le_df.sort_values('Average Life Expectancy', ascending=False)
# set x axis and tick locations
x_axis = np.arange(len(state_data_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_le_df['Average Life Expectancy'], 
        color='#00ACC1', 
        align="edge")
plt.xticks(tick_locations, state_data_df["State"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(70, 81)
# Set Title and labels
plt.title("Average Life Expectancy")
plt.xlabel("State")
plt.ylabel("Years")
plt.savefig('output_data/Average Life Expectancy by state.png', bbox_inches='tight')
plt.show()

# %%
state_ob_df = state_obes_df[['State',
                            'Male obesity prevalence, 2001 (%)',
                            'Female obesity prevalence, 2001 (%)',
                            'Male obesity prevalence, 2009 (%)',
                            'Female obesity  prevalence, 2009 (%)',
                            'Male obesity  prevalence, 2011* (%)',
                            'Female obesity prevalence, 2011* (%)']]
state_ob_df['male avg'] = ((state_obes_df['Male obesity prevalence, 2001 (%)'] + 
                        state_obes_df['Male obesity prevalence, 2009 (%)'] + state_obes_df['Male obesity  prevalence, 2011* (%)'])/3)
state_ob_df['female avg'] = ((state_obes_df['Female obesity prevalence, 2001 (%)'] + 
                        state_obes_df['Female obesity  prevalence, 2009 (%)'] + state_obes_df['Female obesity prevalence, 2011* (%)'])/3)
state_ob_df['Average Obesity Prevalence'] = ((state_ob_df['male avg'] + state_ob_df['female avg'])/2)

state_ob_df = state_ob_df.sort_values('Average Obesity Prevalence', ascending=False)

# set x axis and tick locations
x_axis = np.arange(len(state_data_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_ob_df['Average Obesity Prevalence'], 
        color='#00ACC1', 
        align="edge")
plt.xticks(tick_locations, state_ob_df['State'], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(20, 40)
# Set Title and labels
plt.title("Average Obesity Prevalence")
plt.xlabel("State")
plt.ylabel("Obesity Prevalence")
plt.savefig('output_data/Average Obesity Prevalence by state.png', bbox_inches='tight')
plt.show()
# Out:
# C:\Users\Mastermind\anaconda3\envs\PyEnv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Mastermind\anaconda3\envs\PyEnv\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
state_phys_df = state_PA_df[['State',
                            'Male sufficient physical activity prevalence, 2001 (%)',
                            'Female sufficient physical activity prevalence, 2001 (%)',
                            'Male sufficient physical activity  prevalence, 2009 (%)',
                            'Female sufficient physical activity  prevalence, 2009 (%)',
                            'Male sufficient physical activity  prevalence, 2011* (%)',
                            'Female sufficient physical activity  prevalence, 2011* (%)',]]
state_PA_df['male avg'] = ((state_PA_df['Male sufficient physical activity prevalence, 2001 (%)'] + 
                        state_PA_df['Male sufficient physical activity  prevalence, 2009 (%)'] + state_PA_df['Male sufficient physical activity  prevalence, 2011* (%)'])/3)
state_PA_df['female avg'] = ((state_PA_df['Female sufficient physical activity prevalence, 2001 (%)'] + 
                        state_PA_df['Female sufficient physical activity  prevalence, 2009 (%)'] + state_PA_df['Female sufficient physical activity  prevalence, 2011* (%)'])/3)
state_PA_df['Average Physical Activity Prevalence'] = ((state_PA_df['male avg'] + state_PA_df['female avg'])/2)

state_PA_df = state_PA_df.sort_values('Average Physical Activity Prevalence', ascending=False)

# set x axis and tick locations
x_axis = np.arange(len(state_data_df))
tick_locations = [value+0.4 for value in x_axis]
# create bar chart and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, 
        state_PA_df['Average Physical Activity Prevalence'], 
        color='#00ACC1', 
        align="edge")
plt.xticks(tick_locations, state_ob_df['State'], rotation="vertical")
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(40, 65)
# Set Title and labels
plt.title("Average Physical Activity Prevalence")
plt.xlabel("State")
plt.ylabel("Obesity Prevalence")
plt.savefig('output_data/Average Obesity Prevalence by State.png', bbox_inches='tight')
plt.show()
