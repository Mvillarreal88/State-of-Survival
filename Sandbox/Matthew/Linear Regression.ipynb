# %%
#importing 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
data_csv_path = "Data_csv/state_PA_avg.csv"
initial_data = pd.read_csv(data_csv_path)
del initial_data['Unnamed: 0']
del initial_data['Difference in male sufficient physical activity prevalence, 2001-2009 (percentage points)']
del initial_data['Difference in female sufficient physical activity prevalence, 2001-2009 (percentage points)']
initial_data.head()
# Out:
#         State  Male sufficient physical activity prevalence, 2001 (%)  \
# 0     Alabama                                               52.4
# 1      Alaska                                               63.9
# 2     Arizona                                               61.3
# 3    Arkansas                                               52.4
# 4  California                                               59.4
#
#    Female sufficient physical activity prevalence, 2001 (%)  \
# 0                                               40.4
# 1                                               53.5
# 2                                               51.8
# 3                                               41.4
# 4                                               50.7
#
#    Male sufficient physical activity  prevalence, 2009 (%)  \
# 0                                               51.5
# 1                                               61.9
# 2                                               60.9
# ...

# %%
PA_sum = initial_data.sum()
PA_sum = pd.DataFrame(PA_sum)
PA_sum
# Out:
#                                                                                                     0
# State                                               AlabamaAlaskaArizonaArkansasCaliforniaColorado...
# Male sufficient physical activity prevalence, 2...                                             2881.6
# Female sufficient physical activity prevalence,...                                             2389.2
# Male sufficient physical activity  prevalence, ...                                             2901.2
# Female sufficient physical activity  prevalence...                                             2585.8
# Male sufficient physical activity  prevalence, ...                                             2806.1
# Female sufficient physical activity  prevalence...                                             2634.6

# %%
PA_by_state = pd.DataFrame({
    "Physical activity prevalence": ne_mean,
    "Southeast": se_mean,
    "Midwest": mw_mean,
    "Southwest": sw_mean,
    "West": we_mean
})

life_by_region = life_by_region.T

# %%
data_csv_life = "Data_csv/state_life_avg.csv"
initial_data_life = pd.read_csv(data_csv_life)
del initial_data_life['Unnamed: 0']
del initial_data_life['Difference in male life expectancy, 1985-2010 (years)']
del initial_data_life['Difference in female life expectancy, 1985-2010 (years)']
initial_data_life.head()
# Out:
#         State  Male life expectancy, 1985 (years)  \
# 0     Alabama                                69.1
# 1      Alaska                                70.9
# 2     Arizona                                71.7
# 3    Arkansas                                69.8
# 4  California                                71.7
#
#    Female life expectancy, 1985 (years)  Male life expectancy, 1990 (years)  \
# 0                                  76.9                                69.4
# 1                                  77.7                                72.0
# 2                                  78.8                                72.3
# 3                                  77.5                                70.2
# 4                                  78.3                                72.3
#
#    Female life expectancy, 1990 (years)  Male life expectancy, 1995 (years)  \
# 0                                  77.1                                69.9
# ...

# %%
life_mean = initial_data_life.mean()

# %%
PA_data = initial_data
PA_data
# Out:
#              State  Male sufficient physical activity prevalence, 2001 (%)  \
# 0          Alabama                                               52.4
# 1           Alaska                                               63.9
# 2          Arizona                                               61.3
# 3         Arkansas                                               52.4
# 4       California                                               59.4
# 5         Colorado                                               64.8
# 6      Connecticut                                               58.8
# 7         Delaware                                               54.8
# 8          Florida                                               55.6
# 9          Georgia                                               53.9
# 10          Hawaii                                               68.9
# 11           Idaho                                               62.5
# ...
