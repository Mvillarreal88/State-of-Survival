# %%
#importing 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
data_csv_path = "Data_csv/state_obes_avg.csv"
initial_data = pd.read_csv(data_csv_path)
del initial_data['Unnamed: 0']
initial_data.head()
# Out:
#         State  Male obesity prevalence, 2001 (%)  \
# 0     Alabama                               29.7
# 1      Alaska                               26.7
# 2     Arizona                               25.2
# 3    Arkansas                               28.8
# 4  California                               24.1
#
#    Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                 34.1                               36.1
# 1                                 31.8                               32.8
# 2                                 25.5                               31.6
# 3                                 32.0                               36.1
# 4                                 27.4                               28.7
#
#    Female obesity  prevalence, 2009 (%)  Male obesity  prevalence, 2011* (%)  \
# 0                                  41.2                                 37.3
# ...

# %%
data_csv_PA = "Data_csv/state_PA_avg.csv"
initial_data_PA = pd.read_csv(data_csv_PA)
del initial_data_PA['Unnamed: 0']
initial_data_PA.head()
# Out:
#         State  Male sufficient physical activity prevalence, 2001 (%)  \
# 0     Alabama                                               52.4
# 1      Alaska                                               63.9
# 2     Arizona                                               61.3
# 3    Arkansas                                               52.4
# 4  California                                               59.4
#
#    Female sufficient physical activity prevalence, 2001 (%)  \
# 0                                               40.4
# 1                                               53.5
# 2                                               51.8
# 3                                               41.4
# 4                                               50.7
#
#    Male sufficient physical activity  prevalence, 2009 (%)  \
# 0                                               51.5
# 1                                               61.9
# 2                                               60.9
# ...

# %%
initial_data["Male obesity prevalence 2001-2009(%)"] = initial_data["Male obesity prevalence, 2001 (%)"] + initial_data["Male obesity prevalence, 2009 (%)"]
initial_data["Female obesity prevalence 2001-2009(%)"] = initial_data["Female obesity prevalence, 2001 (%)"] + initial_data["Female obesity prevalence, 2009 (%)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Female obesity prevalence, 2009 (%)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-fe16f27d25c9> in <module>
# ...

# %%
initial_data_PA["Male PA prevalence 2001-2009(%)"] = initial_data["Male obesity prevalence, 2001 (%)"] + initial_data["Male obesity prevalence, 2009 (%)"]
initial_data.head()
