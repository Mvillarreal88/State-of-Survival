# %%
#importing 
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
data_csv_path = "Resources/Obesity.csv"
initial_data = pd.read_csv(data_csv_path)
print(len(initial_data))
del initial_data['Unnamed: 10']
del initial_data['*Methodological changes in the 2011 BRFSS may affect comparability between the 2011 estimates and estimates from earlier years']
initial_data.head()
# Out:
# 3194
#            State   County  Male obesity prevalence, 2001 (%)  \
# 0  United States      NaN                               26.1
# 1        Alabama      NaN                               29.7
# 2        Alabama  Autauga                               30.7
# 3        Alabama  Baldwin                               27.8
# 4        Alabama  Barbour                               32.3
#
#    Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                 28.7                               32.8
# 1                                 34.1                               36.1
# 2                                 32.3                               35.9
# 3                                 28.3                               32.4
# 4                                 42.8                               40.3
#
#    Female obesity  prevalence, 2009 (%)  Male obesity  prevalence, 2011* (%)  \
# 0                                  35.1                                 33.8
# 1                                  41.2                                 37.3
# 2                                  37.4                                 37.1
# 3                                  33.0                                 33.5
# 4                                  51.3                                 41.5
#
#    Female obesity prevalence, 2011* (%)  \
# 0                                  36.1
# 1                                  42.2
# 2                                  38.8
# 3                                  33.9
# 4                                  51.6
#
#    Difference in male obesity prevalence, 2001-2009 (percentage points)  \
# 0                                                6.7
# 1                                                6.4
# 2                                                5.3
# 3                                                4.5
# 4                                                8.0
#
#    Difference in female obesity prevalence, 2001-2009 (percentage points)
# 0                                                6.4
# 1                                                7.1
# 2                                                5.2
# 3                                                4.6
# 4                                                8.5

# %%
#Dropping District of Colombia
initial_data["State"].unique()
# Out:
# array(['United States', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
US_obes_data = initial_data.iloc[:1]
US_obes_data = US_obes_data.drop(['County'], axis = 1)
US_obes_data.head()
# Out:
#            State  Male obesity prevalence, 2001 (%)  \
# 0  United States                               26.1
#
#    Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                 28.7                               32.8
#
#    Female obesity  prevalence, 2009 (%)  Male obesity  prevalence, 2011* (%)  \
# 0                                  35.1                                 33.8
#
#    Female obesity prevalence, 2011* (%)  \
# 0                                  36.1
#
#    Difference in male obesity prevalence, 2001-2009 (percentage points)  \
# 0                                                6.7
#
#    Difference in female obesity prevalence, 2001-2009 (percentage points)
# 0                                                6.4

# %%
state_county_obes = initial_data.drop(labels = 0,
                                   axis = 0,
                                   inplace = False)
state_county_obes.head()
# Out:
#      State   County  Male obesity prevalence, 2001 (%)  \
# 1  Alabama      NaN                               29.7
# 2  Alabama  Autauga                               30.7
# 3  Alabama  Baldwin                               27.8
# 4  Alabama  Barbour                               32.3
# 5  Alabama     Bibb                               35.0
#
#    Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 1                                 34.1                               36.1
# 2                                 32.3                               35.9
# 3                                 28.3                               32.4
# 4                                 42.8                               40.3
# 5                                 38.6                               39.5
#
#    Female obesity  prevalence, 2009 (%)  Male obesity  prevalence, 2011* (%)  \
# 1                                  41.2                                 37.3
# 2                                  37.4                                 37.1
# 3                                  33.0                                 33.5
# 4                                  51.3                                 41.5
# 5                                  43.7                                 40.7
#
#    Female obesity prevalence, 2011* (%)  \
# 1                                  42.2
# 2                                  38.8
# 3                                  33.9
# 4                                  51.6
# 5                                  45.2
#
#    Difference in male obesity prevalence, 2001-2009 (percentage points)  \
# 1                                                6.4
# 2                                                5.3
# 3                                                4.5
# 4                                                8.0
# 5                                                4.4
#
#    Difference in female obesity prevalence, 2001-2009 (percentage points)
# 1                                                7.1
# 2                                                5.2
# 3                                                4.6
# 4                                                8.5
# 5                                                5.1

# %%
#Exporting US dataframe and county's Dataframe to CSV
state_county_obes.to_csv("Data_csv/state_county_obes.csv")
US_obes_data.to_csv("Data_csv/US.csv")

# %%
#Creating a dataframe for the Obesity by State
state_obes_df = state_county_obes.loc[state_county_obes['County'].isna()]
state_obes_df = state_obes_df.reset_index()
del state_obes_df['County']
state_obes_df
# Out:
#     index                 State  Male obesity prevalence, 2001 (%)  \
# 0       1               Alabama                               29.7
# 1      69                Alaska                               26.7
# 2      98               Arizona                               25.2
# 3     114              Arkansas                               28.8
# 4     190            California                               24.1
# 5     249              Colorado                               20.3
# 6     314           Connecticut                               23.7
# 7     323              Delaware                               27.0
# 8     327  District of Columbia                               17.9
# 9     329               Florida                               25.6
# 10    397               Georgia                               27.4
# 11    557                Hawaii                               21.5
# 12    563                 Idaho                               26.4
# 13    608              Illinois                               25.7
# 14    711               Indiana                               28.2
# 15    804                  Iowa                               27.3
# 16    904                Kansas                               26.6
# 17   1010              Kentucky                               28.9
# 18   1131             Louisiana                               29.5
# 19   1196                 Maine                               24.4
# 20   1213              Maryland                               25.4
# 21   1238         Massachusetts                               22.9
# 22   1253              Michigan                               28.0
# 23   1337             Minnesota                               26.1
# 24   1425           Mississippi                               30.3
# 25   1508              Missouri                               28.1
# 26   1624               Montana                               24.0
# 27   1681              Nebraska                               27.3
# 28   1775                Nevada                               26.4
# 29   1793         New Hampshire                               24.3
# 30   1804            New Jersey                               24.9
# 31   1826            New Mexico                               23.1
# 32   1860              New York                               23.9
# 33   1923        North Carolina                               27.1
# 34   2024          North Dakota                               29.1
# 35   2078                  Ohio                               27.5
# 36   2167              Oklahoma                               27.9
# 37   2245                Oregon                               24.6
# 38   2282          Pennsylvania                               27.0
# 39   2350          Rhode Island                               23.5
# 40   2356        South Carolina                               28.4
# 41   2403          South Dakota                               28.1
# 42   2470             Tennessee                               28.9
# 43   2566                 Texas                               27.7
# 44   2821                  Utah                               24.9
# 45   2851               Vermont                               21.8
# 46   2866              Virginia                               26.3
# 47   3001            Washington                               25.2
# 48   3041         West Virginia                               30.1
# 49   3097             Wisconsin                               26.9
# 50   3170               Wyoming                               24.5
#
#     Female obesity prevalence, 2001 (%)  Male obesity prevalence, 2009 (%)  \
# 0                                  34.1                               36.1
# 1                                  31.8                               32.8
# 2                                  25.5                               31.6
# 3                                  32.0                               36.1
# 4                                  27.4                               28.7
# 5                                  21.4                               25.8
# 6                                  24.2                               29.7
# 7                                  29.1                               35.9
# 8                                  28.3                               21.6
# 9                                  27.3                               33.2
# 10                                 31.7                               33.6
# 11                                 19.4                               27.4
# 12                                 27.1                               32.8
# 13                                 29.0                               32.9
# 14                                 30.6                               35.1
# 15                                 28.6                               35.2
# 16                                 28.2                               34.7
# 17                                 31.1                               36.3
# 18                                 33.8                               38.2
# 19                                 26.5                               31.7
# 20                                 28.6                               32.8
# 21                                 23.8                               30.0
# 22                                 31.6                               35.6
# 23                                 27.1                               32.4
# 24                                 36.4                               37.9
# 25                                 30.0                               35.6
# 26                                 24.8                               30.2
# 27                                 28.0                               34.9
# 28                                 25.7                               32.3
# 29                                 24.6                               32.3
# 30                                 26.3                               31.6
# 31                                 27.9                               30.1
# 32                                 26.9                               30.2
# 33                                 31.4                               33.8
# 34                                 28.2                               35.3
# 35                                 29.7                               35.6
# 36                                 29.8                               36.1
# 37                                 27.6                               31.9
# 38                                 29.7                               34.2
# 39                                 25.4                               31.8
# 40                                 31.6                               34.2
# 41                                 28.3                               34.9
# 42                                 31.4                               35.0
# 43                                 31.3                               34.9
# 44                                 25.7                               31.7
# 45                                 24.0                               28.4
# 46                                 28.9                               32.7
# 47                                 27.4                               32.5
# 48                                 32.1                               37.0
# 49                                 28.0                               34.1
# 50                                 25.2                               31.7
#
#     Female obesity  prevalence, 2009 (%)  Male obesity  prevalence, 2011* (%)  \
# 0                                   41.2                                 37.3
# 1                                   36.7                                 33.8
# 2                                   32.8                                 32.4
# 3                                   38.4                                 37.2
# 4                                   32.0                                 29.4
# 5                                   26.9                                 26.8
# 6                                   31.4                                 30.7
# 7                                   37.1                                 36.9
# 8                                   34.3                                 22.4
# 9                                   33.0                                 34.3
# 10                                  37.1                                 34.6
# 11                                  25.4                                 28.4
# 12                                  34.0                                 33.9
# 13                                  35.3                                 33.9
# 14                                  38.5                                 36.3
# 15                                  34.9                                 36.3
# 16                                  36.4                                 35.8
# 17                                  38.4                                 37.5
# 18                                  40.5                                 39.4
# 19                                  33.8                                 32.8
# 20                                  36.1                                 33.9
# 21                                  30.3                                 31.0
# 22                                  38.4                                 36.6
# 23                                  32.5                                 33.4
# 24                                  43.5                                 39.1
# 25                                  38.0                                 36.6
# 26                                  31.2                                 31.3
# 27                                  35.6                                 36.1
# 28                                  31.1                                 33.0
# 29                                  32.0                                 33.5
# 30                                  31.5                                 32.6
# 31                                  34.0                                 31.2
# 32                                  32.9                                 31.2
# 33                                  37.7                                 34.9
# 34                                  34.8                                 36.5
# 35                                  37.6                                 36.7
# 36                                  38.4                                 37.2
# 37                                  33.4                                 32.9
# 38                                  36.7                                 35.3
# 39                                  32.4                                 32.9
# 40                                  39.6                                 35.4
# 41                                  34.8                                 36.0
# 42                                  38.9                                 36.1
# 43                                  38.0                                 36.0
# 44                                  31.6                                 32.6
# 45                                  29.8                                 29.6
# 46                                  35.4                                 33.7
# 47                                  34.0                                 33.6
# 48                                  39.8                                 38.2
# 49                                  35.2                                 35.2
# 50                                  32.2                                 32.8
#
#     Female obesity prevalence, 2011* (%)  \
# 0                                   42.2
# 1                                   37.6
# 2                                   33.8
# 3                                   39.3
# 4                                   32.9
# 5                                   27.7
# 6                                   32.4
# 7                                   37.8
# 8                                   35.3
# 9                                   34.0
# 10                                  38.1
# 11                                  26.1
# 12                                  35.0
# 13                                  36.3
# 14                                  39.5
# 15                                  35.9
# 16                                  37.3
# 17                                  39.3
# 18                                  41.7
# 19                                  34.9
# 20                                  36.9
# 21                                  31.1
# 22                                  39.5
# 23                                  33.3
# 24                                  44.5
# 25                                  38.9
# 26                                  32.0
# 27                                  36.5
# 28                                  32.1
# 29                                  32.7
# 30                                  32.2
# 31                                  34.9
# 32                                  33.8
# 33                                  38.6
# 34                                  35.6
# 35                                  38.5
# 36                                  39.4
# 37                                  34.5
# 38                                  37.6
# 39                                  33.6
# 40                                  40.7
# 41                                  35.6
# 42                                  39.9
# 43                                  38.9
# 44                                  32.6
# 45                                  30.6
# 46                                  36.2
# 47                                  34.8
# 48                                  40.8
# 49                                  36.0
# 50                                  33.0
#
#     Difference in male obesity prevalence, 2001-2009 (percentage points)  \
# 0                                                 6.4
# 1                                                 6.1
# 2                                                 6.4
# 3                                                 7.3
# 4                                                 4.6
# 5                                                 5.5
# 6                                                 6.0
# 7                                                 8.9
# 8                                                 3.7
# 9                                                 7.7
# 10                                                6.2
# 11                                                5.9
# 12                                                6.4
# 13                                                7.2
# 14                                                6.9
# 15                                                7.9
# 16                                                8.1
# 17                                                7.4
# 18                                                8.7
# 19                                                7.2
# 20                                                7.4
# 21                                                7.1
# 22                                                7.6
# 23                                                6.2
# 24                                                7.5
# 25                                                7.4
# 26                                                6.2
# 27                                                7.7
# 28                                                6.0
# 29                                                8.1
# 30                                                6.6
# 31                                                7.1
# 32                                                6.3
# 33                                                6.7
# 34                                                6.2
# 35                                                8.0
# 36                                                8.2
# 37                                                7.2
# 38                                                7.2
# 39                                                8.2
# 40                                                5.8
# 41                                                6.8
# 42                                                6.1
# 43                                                7.2
# 44                                                6.8
# 45                                                6.7
# 46                                                6.4
# 47                                                7.3
# 48                                                6.8
# 49                                                7.3
# 50                                                7.2
#
#     Difference in female obesity prevalence, 2001-2009 (percentage points)
# 0                                                 7.1
# 1                                                 4.9
# 2                                                 7.3
# 3                                                 6.4
# 4                                                 4.6
# 5                                                 5.5
# 6                                                 7.2
# 7                                                 8.1
# 8                                                 6.0
# 9                                                 5.7
# 10                                                5.4
# 11                                                6.0
# 12                                                6.9
# 13                                                6.3
# 14                                                8.0
# 15                                                6.3
# 16                                                8.2
# 17                                                7.3
# 18                                                6.7
# 19                                                7.4
# 20                                                7.5
# 21                                                6.5
# 22                                                6.9
# 23                                                5.4
# 24                                                7.0
# 25                                                8.0
# 26                                                6.4
# 27                                                7.6
# 28                                                5.3
# 29                                                7.4
# 30                                                5.2
# 31                                                6.1
# 32                                                5.9
# 33                                                6.3
# 34                                                6.6
# 35                                                8.0
# 36                                                8.6
# 37                                                5.9
# 38                                                7.0
# 39                                                7.0
# 40                                                8.0
# 41                                                6.5
# 42                                                7.5
# 43                                                6.7
# 44                                                5.9
# 45                                                5.8
# 46                                                6.5
# 47                                                6.6
# 48                                                7.7
# 49                                                7.2
# 50                                                7.0

# %%
state_obes_df.to_csv("Data_csv/state_obes_avg.csv")

# %%
#Seperating the Data by regions
Northeast_obes = state_obes_df[state_obes_df["State"].isin(['Maine', 'Massachusetts', 'Rhode Island','Connecticut',
                                                                 'New Hampshire', 'Vermont', 'New York', 
                                                                 'Pennsylvania', 'New Jersey', 'Delaware', 'Maryland'])]

Southeast_obes = state_obes_df[state_obes_df["State"].isin(['West Virginia', 'Virginia', 'Kentucky', 'Tennessee',
                                                                   'North Carolina', 'South Carolina', 'Georgia', 'Alabama',
                                                                   'Mississippi', 'Arkansas', 'Louisiana', 'Florida'])]
Midwest_obes = state_obes_df[state_obes_df["State"].isin(['Ohio', 'Indiana', 'Michigan', 'Illinois',
                                                                 'Missouri', 'Wisconsin', 'Minnesota', 'Iowa',
                                                                 'Kansas', 'Nebraska', 'South Dakota', 'North Dakota'])]
Southwest_obes = state_obes_df[state_obes_df["State"].isin(['Texas', 'Oklahoma', 'New Mexico', 'Arizona'])]

West_obes = state_obes_df[state_obes_df["State"].isin(['Colorado', 'Wyoming', 'Montana', 'Idaho',
                                                              'Washington', 'Oregon', 'Utah', 'Nevada',
                                                              'California', 'Alaska', 'Hawaii'])]

# %%
#Exporting regional Data
Northeast_obes.to_csv("Data_csv/Northeast_obes.csv")
Southeast_obes.to_csv("Data_csv/Southeast_obes.csv")
Midwest_obes.to_csv("Data_csv/Midwest_obes.csv")
Southwest_obes.to_csv("Data_csv/Southwest_obes.csv")
West_obes.to_csv("Data_csv/West_obes.csv")
