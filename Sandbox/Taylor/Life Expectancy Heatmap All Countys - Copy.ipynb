# %% [markdown]
# Import Dependancies

# %%
# Dependencies
from config import (gkey)
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
from ipywidgets.embed import embed_minimal_html

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#import cleaned county data
county_data = pd.read_csv("Tay_Resources/state_county_w_loc.csv")

county_data["Life Exp Avg"]=((county_data["Difference in male life expectancy, 1985-2010 (years)"]+county_data["Difference in female life expectancy, 1985-2010 (years)"])/2)

# %%
county_geo_data = pd.read_csv("Tay_Resources/uscounties_all.csv")

# %%
complete_county_data = pd.merge(county_geo_data, county_data, on='Location')

# %%
#store all counties with negative life expectancy growth
negative_counties = complete_county_data.loc[(complete_county_data["Life Exp Avg"] < 0),:]
negative_counties
# Out:
#              county state_name              Location      lat       lng  \
# 576          Etowah    Alabama       Etowah, Alabama  34.0453  -86.0348
# 743           Creek   Oklahoma       Creek, Oklahoma  35.9026  -96.3708
# 814          Walker    Alabama       Walker, Alabama  33.8033  -87.2973
# 860            Pike   Kentucky        Pike, Kentucky  37.4691  -82.3958
# 1000         Carter   Oklahoma      Carter, Oklahoma  34.2509  -97.2858
# ...             ...        ...                   ...      ...       ...
# 2742           Coal   Oklahoma        Coal, Oklahoma  34.5882  -96.2978
# 2761        Wheeler      Texas        Wheeler, Texas  35.4012 -100.2698
# 2815         Owsley   Kentucky      Owsley, Kentucky  37.4192  -83.6831
# 2922  Collingsworth      Texas  Collingsworth, Texas  34.9648 -100.2700
# 2940         Harmon   Oklahoma      Harmon, Oklahoma  34.7441  -99.8462
#
#       population  Unnamed: 0     State         County  \
# 576       102748          29   Alabama         Etowah
# 743        71427        2186  Oklahoma          Creek
# 814        64110          65   Alabama         Walker
# 860        59497        1108  Kentucky           Pike
# 1000       48319        2177  Oklahoma         Carter
# ...          ...         ...       ...            ...
# 2742        5581        2182  Oklahoma           Coal
# 2761        5338        2808     Texas        Wheeler
# 2815        4442        1105  Kentucky         Owsley
# 2922        2969        2610     Texas  Collingsworth
# 2940        2710        2196  Oklahoma         Harmon
#
#       Male life expectancy, 1985 (years)  ...  \
# 576                                 69.0  ...
# 743                                 71.9  ...
# 814                                 68.0  ...
# 860                                 67.8  ...
# 1000                                69.1  ...
# ...                                  ...  ...
# 2742                                68.6  ...
# 2761                                71.5  ...
# 2815                                67.7  ...
# 2922                                71.5  ...
# 2940                                69.8  ...
#
#       Female life expectancy, 1995 (years)  \
# 576                                   76.3
# 743                                   78.0
# 814                                   76.1
# 860                                   76.1
# 1000                                  77.8
# ...                                    ...
# 2742                                  77.8
# 2761                                  78.2
# 2815                                  75.8
# 2922                                  78.2
# 2940                                  77.6
#
#       Male life expectancy, 2000 (years)  \
# 576                                 70.2
# 743                                 71.9
# 814                                 67.5
# 860                                 68.6
# 1000                                70.5
# ...                                  ...
# 2742                                70.8
# 2761                                73.1
# 2815                                67.8
# 2922                                73.1
# 2940                                71.0
#
#       Female life expectancy, 2000 (years)  \
# 576                                   76.7
# 743                                   77.1
# 814                                   75.5
# 860                                   75.6
# 1000                                  77.4
# ...                                    ...
# 2742                                  77.1
# 2761                                  78.4
# 2815                                  75.8
# 2922                                  78.4
# 2940                                  76.7
#
#       Male life expectancy, 2005 (years)  \
# 576                                 70.0
# 743                                 71.4
# 814                                 67.0
# 860                                 67.8
# 1000                                70.4
# ...                                  ...
# 2742                                70.1
# 2761                                72.7
# 2815                                66.5
# 2922                                72.7
# 2940                                71.2
#
#       Female life expectancy, 2005 (years)  \
# 576                                   76.4
# 743                                   76.6
# 814                                   73.9
# 860                                   75.6
# 1000                                  75.5
# ...                                    ...
# 2742                                  77.0
# 2761                                  77.9
# 2815                                  74.8
# 2922                                  77.9
# 2940                                  76.9
#
#       Male life expectancy, 2010 (years)  \
# 576                                 70.3
# 743                                 71.2
# 814                                 68.2
# 860                                 67.5
# 1000                                70.8
# ...                                  ...
# 2742                                70.4
# 2761                                72.3
# 2815                                67.5
# 2922                                72.3
# 2940                                71.6
#
#       Female life expectancy, 2010 (years)  \
# 576                                   75.3
# 743                                   76.6
# 814                                   75.0
# 860                                   75.0
# 1000                                  75.1
# ...                                    ...
# 2742                                  75.9
# 2761                                  78.3
# 2815                                  75.3
# 2922                                  78.3
# 2940                                  75.4
#
#       Difference in male life expectancy, 1985-2010 (years)  \
# 576                                                 1.3
# 743                                                -0.7
# 814                                                 0.2
# 860                                                -0.3
# 1000                                                1.7
# ...                                                 ...
# 2742                                                1.8
# 2761                                                0.8
# 2815                                               -0.2
# 2922                                                0.8
# 2940                                                1.8
#
#       Difference in female life expectancy, 1985-2010 (years)  Life Exp Avg
# 576                                                -1.5               -0.10
# 743                                                -1.3               -1.00
# 814                                                -2.3               -1.05
# 860                                                -0.8               -0.55
# 1000                                               -2.1               -0.20
# ...                                                 ...                 ...
# 2742                                               -2.5               -0.35
# 2761                                               -1.0               -0.10
# 2815                                               -1.0               -0.60
# 2922                                               -1.0               -0.10
# 2940                                               -3.4               -0.80
#
# [66 rows x 24 columns]

# %%
complete_county_data = complete_county_data.loc[(complete_county_data["Life Exp Avg"] >= 3),:]

# %%
# Configure gmaps with API key
gmaps.configure(api_key=gkey)

# %% [markdown]
# ## Average Growth in Life Expectancy

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = complete_county_data[["lat", "lng"]]
#life_ex = clean_weather_data['Humidity (%)']

fig1 = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=complete_county_data["Life Exp Avg"],
                                 dissipating=False, max_intensity=15,
                                 point_radius = 2)

fig1.add_layer(heat_layer)

embed_minimal_html('export.html', views=[fig1])

fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))
