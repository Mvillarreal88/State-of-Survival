# %%
# %matplotlib notebook

# %%
 # Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
 # Load in csv
# Take in all of our Regions data and read it into pandas
midwest_life = "Data_csv/Midwest_life_expect.csv"
northeast_life = "Data_csv/Northeast_life_expect.csv"
southeast_life = "Data_csv/Southeast_life_expect.csv"
southwest_life = "Data_csv/Southwest_life_expect.csv"
west_life = "Data_csv/West_life_expect.csv"


midwest_life_df = pd.read_csv(midwest_life)
# northeast_life_df = pd.read_csv(northeast_life)
# southeast_life_df = pd.read_csv(southeast_life)
# southwest_life_df = pd.read_csv(southwest_life)
# west_life_df = pd.read_csv(west_life)

midwest_life_df.head()
# Out:
#    Unnamed: 0     State  Male life expectancy, 1985 (years)  \
# 0          12  Illinois                                70.7
# 1          13   Indiana                                70.9
# 2          14      Iowa                                72.5
# 3          15    Kansas                                72.3
# 4          21  Michigan                                70.4
#
#    Female life expectancy, 1985 (years)  Male life expectancy, 1990 (years)  \
# 0                                  77.5                                71.1
# 1                                  77.7                                71.6
# 2                                  79.3                                73.3
# 3                                  79.0                                73.1
# 4                                  77.3                                71.5
#
#    Female life expectancy, 1990 (years)  Male life expectancy, 1995 (years)  \
# ...

# %%
# Out:
#    Unnamed: 0_x     State  Male life expectancy, 1985 (years)_x  \
# 0            12  Illinois                                  70.7
# 1            13   Indiana                                  70.9
# 2            14      Iowa                                  72.5
# 3            15    Kansas                                  72.3
# 4            21  Michigan                                  70.4
#
#    Female life expectancy, 1985 (years)_x  \
# 0                                    77.5
# 1                                    77.7
# 2                                    79.3
# 3                                    79.0
# 4                                    77.3
#
#    Male life expectancy, 1990 (years)_x  \
# 0                                  71.1
# 1                                  71.6
# 2                                  73.3
# 3                                  73.1
# 4                                  71.5
#
#    Female life expectancy, 1990 (years)_x  \
# ...

# %%
# Merge our newly combined dataframe with the Southeast_life
combined_life_df = pd.merge(combined_life_df, wrestlers_2015_df, how="outer", on="Stay")
combined_wrestlers_df

# %%
# DATA 
Life_Expectancy_by_Gender = ["Male life expectancy, 1985 (years)", "Male life expectancy, 2010 (years)","Female life expectancy, 1985 (years)", "Female life expectancy, 2010 (years)"]
Years = [70.8, 77.8, 76.1, 80.8] 

x_axis = np.arange(0, len(Life_Expectancy_by_Gender))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("Life Expectancy 1985 to 2010")
plt.xlabel("Gender")
plt.ylabel("Years")

plt.xlim(-0.5, len(Life_Expectancy_by_Gender)-.25)
plt.ylim(0, max(years) +20)


plt.bar(x_axis, Years, facecolor="red", alpha=0.50, align="center")
plt.xticks(tick_locations, Life_Expectancy_by_Gender)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-70d5a6478e88> in <module>
#       9 plt.ylabel("Gender")
#      10
# ---> 11 plt.xlim(-0.5, len(Life_Expectancy_by_Gender)-.5)
#      12 plt.ylim(0, max(years)+10)
#      13
#
# NameError: name 'Life_Expectancy_by_Gender' is not defined
